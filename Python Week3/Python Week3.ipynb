# %%
#Bài 1

import math
xA = int(input())
yA = int(input())
xB = int(input())
yB = int(input())
xC = int(input())
yC = int(input())

ab = math.sqrt((xB - xA)**2 + (yB - yA)**2)
ac = math.sqrt((xC - xA)**2 + (yC - yA)**2)
bc = math.sqrt((xC - xB)**2 + (yC - yB)**2)

if(ab + ac > bc and ab + bc > ac and ac + bc > ab):
    print('TAM GIÁC')
else:
    print('KHÔNG PHẢI TAM GIÁC')
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# KHÔNG PHẢI TAM GIÁC

# %%
#Bài 2

def reverse(number, m):
    n = 0
    tmp = 1

    for i in range(m):
        tmp *= 10
    x = number % tmp
    tmp2 = number // tmp

    while x > 0:
        last = x % 10
        n = n * 10 + last
        x = x // 10

    result = tmp2 * tmp + n
    return result


n = int(input())
m = int(input())

for _ in range(n):
    number = int(input())
    result = reverse(number, m)
    print(result)
# Out:
# 2
# 3
# 123456
# 123654
# 456789
# 456987

# %%
#Bài 3

k = int(input())
for i in range(k):
    name = input()
    p1 = int(input())
    p2 = int(input())
    sum = p1 +p2
    if(sum >= 190):
        print(i+1, name, sum, 'Xuất sắc\n')
    elif(sum >=150):
        print(i+1,name,sum,'Giỏi\n')
    elif(sum >= 100):
        print(i+1,name,sum,'Khá\n')
    else:
        print(i+1,name,sum,'Yếu\n')
# Out:
# 2
# A
# 50
# 60
# 1 A 110 Khá
#
# B
# 70
# 80
# 2 B 150 Giỏi
